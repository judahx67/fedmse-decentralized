# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the font family to DejaVu Sans
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']

# Data from the new table
agents = ['Gateway 1', 'Gateway 2', 'Gateway 3', 'Gateway 4', 'Gateway 5', 'Gateway 6', 'Gateway 7', 'Gateway 8', 'Gateway 9', 'Gateway 10', 'Average']
x = np.arange(len(agents))

# Autoencoder
autoencoder_fedavg_means = [98.77, 97.81, 98.43, 99.42, 99.75, 99.23, 98.3, 100, 99.03, 99.97, 99.07]
autoencoder_fedavg_stds = [0.33, 0.5, 0.47, 0.2, 0.1, 0.26, 0.35, 0, 0.17, 0.02, 0.24]

autoencoder_fedprox_means = [98.53, 97.53, 98.1, 99.39, 99.75, 99.16, 98.08, 100, 98.94, 99.97, 98.95]
autoencoder_fedprox_stds = [0.51, 0.59, 0.57, 0.25, 0.04, 0.31, 0.45, 0, 0.17, 0.02, 0.29]

autoencoder_mseavg_means = [98.54, 97.51, 98.02, 99.32, 99.73, 99.09, 98.06, 100, 98.93, 99.97, 98.92]
autoencoder_mseavg_stds = [0.42, 0.73, 0.58, 0.3, 0.07, 0.35, 0.39, 0, 0.2, 0.02, 0.31]

# SAE-CEN
sae_cen_fedavg_means = [97.93, 97.73, 97.8, 99.22, 99.84, 98.92, 97.82, 100, 98.38, 99.95, 98.76]
sae_cen_fedavg_stds = [0.75, 0.75, 0.55, 1, 0.06, 0.92, 0.78, 0, 0.76, 0.02, 0.56]

sae_cen_fedprox_means = [97.67, 97.76, 97.74, 98.52, 99.81, 98.22, 97.59, 100, 98.06, 99.95, 98.53]
sae_cen_fedprox_stds = [1.18, 0.73, 0.49, 0.82, 0.07, 0.69, 1.28, 0, 1.22, 0.03, 0.65]

sae_cen_mseavg_means = [98.68, 97.83, 98.26, 99.31, 99.86, 99.16, 98.3, 100, 98.72, 99.95, 99.01]
sae_cen_mseavg_stds = [0.64, 0.82, 0.85, 0.7, 0.05, 0.41, 0.79, 0, 0.54, 0.02, 0.48]

# Bar width
bar_width = 0.11
avg_bar_width = 0.25  # Wider bar for the average column

# Plotting
plt.figure(figsize=(14, 8))

# Plotting Autoencoder FedAvg
plt.bar(x[:-1] - 2.5*bar_width, autoencoder_fedavg_means[:-1], bar_width, yerr=autoencoder_fedavg_stds[:-1], label='AE+FedAvg', capsize=2, color='#A7AEAB', edgecolor='black')
# Plotting Autoencoder FedProx
plt.bar(x[:-1] - 1.5*bar_width, autoencoder_fedprox_means[:-1], bar_width, yerr=autoencoder_fedprox_stds[:-1], label='AE+FedProx', capsize=2, color='#958BF7', edgecolor='black')
# Plotting AE MSE-Avg
plt.bar(x[:-1] - 0.5*bar_width, autoencoder_mseavg_means[:-1], bar_width, yerr=autoencoder_mseavg_stds[:-1], label='AE+MSEAvg', capsize=2, color='#A3FFD7', edgecolor='black')

# Plotting SAE-CEN FedAvg
plt.bar(x[:-1] + 0.5*bar_width, sae_cen_fedavg_means[:-1], bar_width, yerr=sae_cen_fedavg_stds[:-1], label='SAE-CEN+FedAvg', capsize=2, color='#98b11c', edgecolor='black')
# Plotting SAE-CEN FedProx
plt.bar(x[:-1] + 1.5*bar_width, sae_cen_fedprox_means[:-1], bar_width, yerr=sae_cen_fedprox_stds[:-1], label='SAE-CEN+FedProx', capsize=2, color='#82C8F3', edgecolor='black')
# Plotting SAE-CEN MSE-Avg
plt.bar(x[:-1] + 2.5*bar_width, sae_cen_mseavg_means[:-1], bar_width, yerr=sae_cen_mseavg_stds[:-1], label='SAE-CEN+MSEAvg', capsize=2, color='#F5E132', edgecolor='black')

# Emphasizing the average column
plt.bar(x[-1] - 2.5*bar_width, autoencoder_fedavg_means[-1], bar_width, yerr=autoencoder_fedavg_stds[-1], capsize=2, color='#A7AEAB', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] - 1.5*bar_width, autoencoder_fedprox_means[-1], bar_width, yerr=autoencoder_fedprox_stds[-1], capsize=2, color='#958BF7', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] - 0.5*bar_width, autoencoder_mseavg_means[-1], bar_width, yerr=autoencoder_mseavg_stds[-1], capsize=2, color='#A3FFD7', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] + 0.5*bar_width, sae_cen_fedavg_means[-1], bar_width, yerr=sae_cen_fedavg_stds[-1], capsize=2, color='#98b11c', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] + 1.5*bar_width, sae_cen_fedprox_means[-1], bar_width, yerr=sae_cen_fedprox_stds[-1], capsize=2, color='#82C8F3', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] + 2.5*bar_width, sae_cen_mseavg_means[-1], bar_width, yerr=sae_cen_mseavg_stds[-1], capsize=2, color='#F5E132', edgecolor='black', hatch='/', label='_nolegend_')

# Adding labels and title with bold font and larger title size
plt.xticks(x, agents, rotation=45, fontsize=18)
plt.xlabel('Agents', fontweight='bold', fontsize=18)
plt.ylabel('Mean AUC ± Std Dev (%)', fontweight='bold', fontsize=18)
plt.title('Model accuracy for different agents in the IID setting', fontweight='bold', fontsize=18)
plt.legend(loc='upper right', fontsize=16)
plt.ylim(95, 100)
plt.yticks(np.arange(97, 105, 2), fontsize=18)
plt.grid(True, axis='y')
plt.grid(False, axis='x')
plt.gca().set_axisbelow(True)

# Save the plot to a PDF file
plt.tight_layout()
# plt.savefig("iid-exp1.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the font family to DejaVu Sans
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']

# Data from the new table
agents = ['Gateway 1', 'Gateway 2', 'Gateway 3', 'Gateway 4', 'Gateway 5', 'Gateway 6', 'Gateway 7', 'Gateway 8', 'Gateway 9', 'Gateway 10', 'Average']
x = np.arange(len(agents))

# Autoencoder
autoencoder_fedavg_means = [91, 99.58, 88.68, 89.42, 97.96, 92.7, 94.62, 95.84, 98.05, 99.52, 94.74]
autoencoder_fedavg_stds = [4.84, 0.03, 5.76, 5.14, 1.19, 3.52, 2.81, 2.14, 1.39, 0.09, 2.69]

autoencoder_fedprox_means = [87.96, 99.58, 87.7, 88.72, 97.53, 91.75, 93.94, 95.47, 97.65, 99.52, 93.98]
autoencoder_fedprox_stds = [6.25, 0.03, 5.87, 4.93, 1.17, 3.9, 3.25, 2.2, 1.33, 0.09, 2.9]

autoencoder_mseavg_means = [86.61, 99.56, 86.8, 86.14, 96.91, 89.47, 92.53, 94.18, 97.04, 99.48, 92.87]
autoencoder_mseavg_stds = [1.92, 0, 4.84, 2.48, 0.28, 1.13, 0.53, 0.94, 0.5, 0, 1.26]

# SAE-CEN
sae_cen_fedavg_means = [96.65, 99.62, 93.55, 94.4, 98.63, 93.84, 96.18, 97.51, 99.14, 99.77, 96.93]
sae_cen_fedavg_stds = [1, 0.05, 1.09, 1.11, 0.47, 2.03, 0.34, 0.55, 0.33, 0.05, 0.7]

sae_cen_fedprox_means = [97.44, 99.61, 93.82, 94.41, 98.76, 95.38, 96.63, 97.87, 99.02, 99.81, 97.28]
sae_cen_fedprox_stds = [1.62, 0.09, 1.3, 1.66, 0.62, 0.87, 0.94, 0.5, 0.71, 0.1, 0.84]

sae_cen_mseavg_means = [97.25, 99.64, 94.58, 94.97, 98.69, 94.43, 96.58, 97.73, 99.3, 99.77, 97.3]
sae_cen_mseavg_stds = [1.04, 0.09, 0.89, 1.03, 0.46, 0.25, 0.58, 0.07, 0.42, 0.05, 0.49]

# Bar width
bar_width = 0.1
avg_bar_width = 0.25  # Wider bar for the average column

# Plotting
plt.figure(figsize=(14, 8))

# Plotting Autoencoder FedAvg
plt.bar(x[:-1] - 2.5*bar_width, autoencoder_fedavg_means[:-1], bar_width, yerr=autoencoder_fedavg_stds[:-1], label='AE+FedAvg', capsize=2, color='#A7AEAB', edgecolor='black')
# Plotting Autoencoder FedProx
plt.bar(x[:-1] - 1.5*bar_width, autoencoder_fedprox_means[:-1], bar_width, yerr=autoencoder_fedprox_stds[:-1], label='AE+FedProx', capsize=2, color='#958BF7', edgecolor='black')
# Plotting AE MSE-Avg
plt.bar(x[:-1] - 0.5*bar_width, autoencoder_mseavg_means[:-1], bar_width, yerr=autoencoder_mseavg_stds[:-1], label='AE+MSEAvg', capsize=2, color='#A3FFD7', edgecolor='black')

# Plotting SAE-CEN FedAvg
plt.bar(x[:-1] + 0.5*bar_width, sae_cen_fedavg_means[:-1], bar_width, yerr=sae_cen_fedavg_stds[:-1], label='SAE-CEN+FedAvg', capsize=2, color='#98b11c', edgecolor='black')
# Plotting SAE-CEN FedProx
plt.bar(x[:-1] + 1.5*bar_width, sae_cen_fedprox_means[:-1], bar_width, yerr=sae_cen_fedprox_stds[:-1], label='SAE-CEN+FedProx', capsize=2, color='#82C8F3', edgecolor='black')
# Plotting SAE-CEN MSE-Avg
plt.bar(x[:-1] + 2.5*bar_width, sae_cen_mseavg_means[:-1], bar_width, yerr=sae_cen_mseavg_stds[:-1], label='SAE-CEN+MSEAvg', capsize=2, color='#F5E132', edgecolor='black')

# Emphasizing the average column
plt.bar(x[-1] - 2.5*bar_width, autoencoder_fedavg_means[-1], bar_width, yerr=autoencoder_fedavg_stds[-1], capsize=2, color='#A7AEAB', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] - 1.5*bar_width, autoencoder_fedprox_means[-1], bar_width, yerr=autoencoder_fedprox_stds[-1], capsize=2, color='#958BF7', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] - 0.5*bar_width, autoencoder_mseavg_means[-1], bar_width, yerr=autoencoder_mseavg_stds[-1], capsize=2, color='#A3FFD7', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] + 0.5*bar_width, sae_cen_fedavg_means[-1], bar_width, yerr=sae_cen_fedavg_stds[-1], capsize=2, color='#98b11c', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] + 1.5*bar_width, sae_cen_fedprox_means[-1], bar_width, yerr=sae_cen_fedprox_stds[-1], capsize=2, color='#82C8F3', edgecolor='black', hatch='/', label='_nolegend_')
plt.bar(x[-1] + 2.5*bar_width, sae_cen_mseavg_means[-1], bar_width, yerr=sae_cen_mseavg_stds[-1], capsize=2, color='#F5E132', edgecolor='black', hatch='/', label='_nolegend_')

# Adding labels and title with bold font and larger title size
plt.xticks(x, agents, rotation=45, fontsize=18)
plt.xlabel('Agents', fontweight='bold', fontsize=18)
plt.ylabel('Mean AUC ± Std Dev (%)', fontweight='bold', fontsize=18)
plt.title('Model accuracy for different agents in the non-IID setting', fontweight='bold', fontsize=18)
plt.legend(loc='lower right', fontsize=16)
plt.ylim(80, 100)
plt.yticks(np.arange(80, 110, 5), fontsize=18)
plt.grid(True, axis='y')
plt.grid(False, axis='x')
plt.gca().set_axisbelow(True)

# Save the plot to a PDF file
plt.tight_layout()
# plt.savefig("noniid-exp1.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the font family to DejaVu Sans
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']

# Data from the new table
client_ratios = ['50%', '60%', '70%', '80%', '90%', '100%']
x = np.arange(len(client_ratios))

# Autoencoder
autoencoder_fedavg_means = [94.74, 92.85, 95.28, 93.14, 92.83, 94.06]
autoencoder_fedavg_stds = [2.69, 1.05, 1.45, 1.29, 1.18, 1.31]

autoencoder_fedprox_means = [93.98, 93.36, 94.39, 92.32, 92.61, 93.65]
autoencoder_fedprox_stds = [2.9, 1.26, 1.36, 1.22, 0.97, 1.35]

autoencoder_mseavg_means = [92.87, 93.43, 94.09, 93.63, 92.7, 93.6]
autoencoder_mseavg_stds = [1.26, 1.05, 1.97, 1.7, 1.17, 1.05]

# SAE-CEN
sae_cen_fedavg_means = [96.93, 97.31, 97.04, 97.06, 97.24, 97.3]
sae_cen_fedavg_stds = [0.7, 0.68, 0.8, 0.77, 1.21, 0.71]

sae_cen_fedprox_means = [97.28, 96.92, 97.03, 97.13, 97.15, 97.29]
sae_cen_fedprox_stds = [0.84, 1.1, 0.74, 0.81, 0.73, 0.46]

sae_cen_mseavg_means = [97.3, 97.08, 97, 97.21, 97.11, 97.21]
sae_cen_mseavg_stds = [0.49, 0.88, 1.09, 0.75, 0.88, 0.63]

# Bar width
bar_width = 0.1
avg_bar_width = 0.25  # Wider bar for the average column

# Plotting
plt.figure(figsize=(18, 8))

# Plotting Autoencoder FedAvg
bars1 = plt.bar(x - 2.5*bar_width, autoencoder_fedavg_means, bar_width, yerr=autoencoder_fedavg_stds, label='AE+FedAvg', capsize=2, color='#A7AEAB', edgecolor='black')
# Plotting Autoencoder FedProx
bars2 = plt.bar(x - 1.5*bar_width, autoencoder_fedprox_means, bar_width, yerr=autoencoder_fedprox_stds, label='AE+FedProx', capsize=2, color='#958BF7', edgecolor='black')
# Plotting AE MSE-Avg
bars3 = plt.bar(x - 0.5*bar_width, autoencoder_mseavg_means, bar_width, yerr=autoencoder_mseavg_stds, label='AE+MSEAvg', capsize=2, color='#A3FFD7', edgecolor='black')

# Plotting SAE-CEN FedAvg
bars4 = plt.bar(x + 0.5*bar_width, sae_cen_fedavg_means, bar_width, yerr=sae_cen_fedavg_stds, label='SAE-CEN+FedAvg', capsize=2, color='#98b11c', edgecolor='black')
# Plotting SAE-CEN FedProx
bars5 = plt.bar(x + 1.5*bar_width, sae_cen_fedprox_means, bar_width, yerr=sae_cen_fedprox_stds, label='SAE-CEN+FedProx', capsize=2, color='#82C8F3', edgecolor='black')
# Plotting SAE-CEN MSE-Avg
bars6 = plt.bar(x + 2.5*bar_width, sae_cen_mseavg_means, bar_width, yerr=sae_cen_mseavg_stds, label='SAE-CEN+MSEAvg', capsize=2, color='#F5E132', edgecolor='black')

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2.0, height+0.5, f'{height:.2f}', ha='center', va='bottom', fontsize=10, rotation=60)

# add_labels(bars1)
# add_labels(bars2)
# add_labels(bars3)
# add_labels(bars4)
# add_labels(bars5)
# add_labels(bars6)

# Adding labels and title with bold font and larger title size
plt.xticks(x, client_ratios, rotation=0, fontsize=18)
plt.xlabel('Client Ratio', fontweight='bold', fontsize=18)
plt.ylabel('Mean AUC ± Std Dev (%)', fontweight='bold', fontsize=18)
plt.title('Performance comparison of SAE-CEN and Autoencoder based on client ratio in the non-IID scenario', fontweight='bold', fontsize=18)
plt.legend(loc='upper right', fontsize=16)
plt.ylim(90, 100)
plt.yticks(np.arange(90, 104, 2), fontsize=18)
plt.grid(True, axis='y')
plt.grid(False, axis='x')
plt.gca().set_axisbelow(True)

# Save the plot to a PDF file
plt.tight_layout()
plt.savefig("noniid-exp2.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the font family to DejaVu Sans
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']

# Data from the new table
client_ratios = ['50%', '60%', '70%', '80%', '90%', '100%']
x = np.arange(len(client_ratios))

# Autoencoder
autoencoder_fedavg_means = [99.07, 98.48, 98.13, 97.96, 97.24, 97.61]
autoencoder_fedavg_stds = [0.24, 0.44, 0.7, 0.93, 0.86, 0.52]

autoencoder_fedprox_means = [98.95, 98.12, 98.17, 97.77, 97.27, 97.34]
autoencoder_fedprox_stds = [0.29, 0.45, 0.56, 0.69, 0.85, 0.36]

autoencoder_mseavg_means = [98.92, 98.47, 98.04, 97.66, 97.06, 97.29]
autoencoder_mseavg_stds = [0.31, 0.37, 0.54, 0.78, 0.89, 0.63]

# SAE-CEN
sae_cen_fedavg_means = [98.76, 98.76, 98.51, 98.77, 98.24, 98.72]
sae_cen_fedavg_stds = [0.56, 0.42, 0.74, 0.85, 1.39, 0.56]

sae_cen_fedprox_means = [98.53, 98.85, 98.69, 98.79, 98.7, 98.61]
sae_cen_fedprox_stds = [0.65, 0.56, 0.37, 0.54, 0.71, 0.64]

sae_cen_mseavg_means = [99.01, 98.96, 98.44, 98.71, 98.6, 98.69]
sae_cen_mseavg_stds = [0.48, 0.68, 0.67, 0.8, 0.56, 0.69]

# Bar width
bar_width = 0.1
avg_bar_width = 0.25  # Wider bar for the average column

# Plotting
plt.figure(figsize=(18, 8))

# Plotting Autoencoder FedAvg
bars1 = plt.bar(x - 2.5*bar_width, autoencoder_fedavg_means, bar_width, yerr=autoencoder_fedavg_stds, label='AE+FedAvg', capsize=2, color='#A7AEAB', edgecolor='black')
# Plotting Autoencoder FedProx
bars2 = plt.bar(x - 1.5*bar_width, autoencoder_fedprox_means, bar_width, yerr=autoencoder_fedprox_stds, label='AE+FedProx', capsize=2, color='#958BF7', edgecolor='black')
# Plotting AE MSE-Avg
bars3 = plt.bar(x - 0.5*bar_width, autoencoder_mseavg_means, bar_width, yerr=autoencoder_mseavg_stds, label='AE+MSEAvg', capsize=2, color='#A3FFD7', edgecolor='black')

# Plotting SAE-CEN FedAvg
bars4 = plt.bar(x + 0.5*bar_width, sae_cen_fedavg_means, bar_width, yerr=sae_cen_fedavg_stds, label='SAE-CEN+FedAvg', capsize=2, color='#98b11c', edgecolor='black')
# Plotting SAE-CEN FedProx
bars5 = plt.bar(x + 1.5*bar_width, sae_cen_fedprox_means, bar_width, yerr=sae_cen_fedprox_stds, label='SAE-CEN+FedProx', capsize=2, color='#82C8F3', edgecolor='black')
# Plotting SAE-CEN MSE-Avg
bars6 = plt.bar(x + 2.5*bar_width, sae_cen_mseavg_means, bar_width, yerr=sae_cen_mseavg_stds, label='SAE-CEN+MSEAvg', capsize=2, color='#F5E132', edgecolor='black')

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2.0, height+0.5, f'{height:.2f}', ha='center', va='bottom', fontsize=10, rotation=60)

# add_labels(bars1)
# add_labels(bars2)
# add_labels(bars3)
# add_labels(bars4)
# add_labels(bars5)
# add_labels(bars6)

# Adding labels and title with bold font and larger title size
plt.xticks(x, client_ratios, rotation=0, fontsize=18)
plt.xlabel('Client Ratio', fontweight='bold', fontsize=18)
plt.ylabel('Mean AUC ± Std Dev (%)', fontweight='bold', fontsize=18)
plt.title('Performance comparison of SAE-CEN and Autoencoder based on client ratio in the IID scenario', fontweight='bold', fontsize=18)
plt.legend(loc='lower left', fontsize=16)
plt.ylim(95, 100)
plt.yticks(np.arange(95, 101, 2), fontsize=18)
plt.grid(True, axis='y')
plt.grid(False, axis='x')
plt.gca().set_axisbelow(True)

# Save the plot to a PDF file
plt.tight_layout()
plt.savefig("iid-exp2.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the font family to DejaVu Sans
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']

# Data from the new table
network_scales = ['10-client', '20-client', '30-client', '40-client', '50-client']
x = np.arange(len(network_scales))

# Autoencoder
autoencoder_fedavg_means = [99.07, 98.43, 97.4, 97.05, 97.01]
autoencoder_fedavg_stds = [0.24, 0.26, 0.67, 0.97, 0.75]

autoencoder_fedprox_means = [98.95, 98.51, 97.45, 97.16, 96.74]
autoencoder_fedprox_stds = [0.29, 0.21, 0.47, 0.66, 0.56]

autoencoder_mseavg_means = [98.92, 98.56, 97.37, 96.95, 97.2]
autoencoder_mseavg_stds = [0.31, 0.31, 0.57, 0.95, 0.82]

# SAE-CEN
sae_cen_fedavg_means = [98.76, 98.59, 98.27, 98.38, 98.33]
sae_cen_fedavg_stds = [0.56, 0.37, 0.43, 0.42, 0.63]

sae_cen_fedprox_means = [98.53, 99.02, 98.34, 98.38, 98.16]
sae_cen_fedprox_stds = [0.65, 0.39, 0.5, 0.42, 0.37]

sae_cen_mseavg_means = [99.01, 98.54, 98.34, 98.45, 98.2]
sae_cen_mseavg_stds = [0.48, 0.37, 0.55, 0.39, 0.56]

# Bar width
bar_width = 0.1
avg_bar_width = 0.25  # Wider bar for the average column

# Plotting
plt.figure(figsize=(18, 8))

# Plotting Autoencoder FedAvg
bars1 = plt.bar(x - 2.5*bar_width, autoencoder_fedavg_means, bar_width, yerr=autoencoder_fedavg_stds, label='AE+FedAvg', capsize=2, color='#A7AEAB', edgecolor='black')
# Plotting Autoencoder FedProx
bars2 = plt.bar(x - 1.5*bar_width, autoencoder_fedprox_means, bar_width, yerr=autoencoder_fedprox_stds, label='AE+FedProx', capsize=2, color='#958BF7', edgecolor='black')
# Plotting AE MSE-Avg
bars3 = plt.bar(x - 0.5*bar_width, autoencoder_mseavg_means, bar_width, yerr=autoencoder_mseavg_stds, label='AE+MSEAvg', capsize=2, color='#A3FFD7', edgecolor='black')

# Plotting SAE-CEN FedAvg
bars4 = plt.bar(x + 0.5*bar_width, sae_cen_fedavg_means, bar_width, yerr=sae_cen_fedavg_stds, label='SAE-CEN+FedAvg', capsize=2, color='#98b11c', edgecolor='black')
# Plotting SAE-CEN FedProx
bars5 = plt.bar(x + 1.5*bar_width, sae_cen_fedprox_means, bar_width, yerr=sae_cen_fedprox_stds, label='SAE-CEN+FedProx', capsize=2, color='#82C8F3', edgecolor='black')
# Plotting SAE-CEN MSE-Avg
bars6 = plt.bar(x + 2.5*bar_width, sae_cen_mseavg_means, bar_width, yerr=sae_cen_mseavg_stds, label='SAE-CEN+MSEAvg', capsize=2, color='#F5E132', edgecolor='black')

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2.0, height + 0.1, f'{height:.2f}', ha='center', va='bottom', fontsize=8, rotation=45)

# add_labels(bars1)
# add_labels(bars2)
# add_labels(bars3)
# add_labels(bars4)
# add_labels(bars5)
# add_labels(bars6)

# Adding labels and title with bold font and larger title size
plt.xticks(x, network_scales, rotation=0, fontsize=18)
plt.xlabel('Network Scale', fontweight='bold', fontsize=18)
plt.ylabel('Mean AUC ± Std Dev (%)', fontweight='bold', fontsize=18)
plt.title('Performance comparison between SAE-CEN and Autoencoder on different network scales in the IID scenario', fontweight='bold', fontsize=18)
plt.legend(loc='lower left', fontsize=16)
plt.ylim(95, 100)
plt.yticks(np.arange(95, 100, 1), fontsize=18)
plt.grid(True, axis='y')
plt.grid(False, axis='x')
plt.gca().set_axisbelow(True)

# Save the plot to a PDF file
plt.tight_layout()
# plt.savefig("iid-exp3.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the font family to DejaVu Sans
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']

# Data from the new table
network_scales = ['10-client', '20-client', '30-client', '40-client', '50-client']
x = np.arange(len(network_scales))

# Autoencoder
autoencoder_fedavg_means = [94.74, 95.72, 96.95, 95.99, 96.3]
autoencoder_fedavg_stds = [2.69, 1.42, 1.51, 1.83, 0.98]

autoencoder_fedprox_means = [93.98, 95.62, 96.96, 95.78, 96.39]
autoencoder_fedprox_stds = [2.9, 1.18, 1.19, 1.78, 0.85]

autoencoder_mseavg_means = [92.87, 95.68, 96.98, 95.72, 96.42]
autoencoder_mseavg_stds = [1.26, 1.11, 1.43, 1.8, 2.37]

# SAE-CEN
sae_cen_fedavg_means = [96.93, 97.17, 97.54, 97.81, 98.41]
sae_cen_fedavg_stds = [0.7, 0.9, 0.61, 0.94, 0.72]

sae_cen_fedprox_means = [97.28, 97.19, 97.65, 97.58, 98.36]
sae_cen_fedprox_stds = [0.84, 0.83, 0.54, 0.84, 0.65]

sae_cen_mseavg_means = [97.3, 97.29, 97.73, 97.77, 98.52]
sae_cen_mseavg_stds = [0.49, 0.96, 0.56, 1.01, 0.51]

# Bar width
bar_width = 0.1
avg_bar_width = 0.25  # Wider bar for the average column

# Plotting
plt.figure(figsize=(18, 8))

# Plotting Autoencoder FedAvg
bars1 = plt.bar(x - 2.5*bar_width, autoencoder_fedavg_means, bar_width, yerr=autoencoder_fedavg_stds, label='AE+FedAvg', capsize=2, color='#A7AEAB', edgecolor='black')
# Plotting Autoencoder FedProx
bars2 = plt.bar(x - 1.5*bar_width, autoencoder_fedprox_means, bar_width, yerr=autoencoder_fedprox_stds, label='AE+FedProx', capsize=2, color='#958BF7', edgecolor='black')
# Plotting AE MSE-Avg
bars3 = plt.bar(x - 0.5*bar_width, autoencoder_mseavg_means, bar_width, yerr=autoencoder_mseavg_stds, label='AE+MSEAvg', capsize=2, color='#A3FFD7', edgecolor='black')

# Plotting SAE-CEN FedAvg
bars4 = plt.bar(x + 0.5*bar_width, sae_cen_fedavg_means, bar_width, yerr=sae_cen_fedavg_stds, label='SAE-CEN+FedAvg', capsize=2, color='#98b11c', edgecolor='black')
# Plotting SAE-CEN FedProx
bars5 = plt.bar(x + 1.5*bar_width, sae_cen_fedprox_means, bar_width, yerr=sae_cen_fedprox_stds, label='SAE-CEN+FedProx', capsize=2, color='#82C8F3', edgecolor='black')
# Plotting SAE-CEN MSE-Avg
bars6 = plt.bar(x + 2.5*bar_width, sae_cen_mseavg_means, bar_width, yerr=sae_cen_mseavg_stds, label='SAE-CEN+MSEAvg', capsize=2, color='#F5E132', edgecolor='black')

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2.0, height + 0.1, f'{height:.2f}', ha='center', va='bottom', fontsize=8, rotation=45)

# add_labels(bars1)
# add_labels(bars2)
# add_labels(bars3)
# add_labels(bars4)
# add_labels(bars5)
# add_labels(bars6)

# Adding labels and title with bold font and larger title size
plt.xticks(x, network_scales, rotation=0, fontsize=18)
plt.xlabel('Network Scale', fontweight='bold', fontsize=18)
plt.ylabel('Mean AUC ± Std Dev (%)', fontweight='bold', fontsize=18)
plt.title('Performance comparison between SAE-CEN and Autoencoder on different network scales in the non-IID scenario', fontweight='bold', fontsize=18)
plt.legend(loc='lower right', fontsize=16)
plt.ylim(90, 100)
plt.yticks(np.arange(90, 100, 1), fontsize=18)
plt.grid(True, axis='y')
plt.grid(False, axis='x')
plt.gca().set_axisbelow(True)

# Save the plot to a PDF file
plt.tight_layout()
plt.savefig("noniid-exp3.pdf")

plt.show()
